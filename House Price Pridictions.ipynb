# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('home_data.csv')

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.nunique()
# Out:
# id               21436
# date               372
# price             4032
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
df.drop(['id','date'],axis=1,inplace=True)
df.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3       1.00         1180      5650     1.0           0
# 1  538000         3       2.25         2570      7242     2.0           0
# 2  180000         2       1.00          770     10000     1.0           0
# 3  604000         4       3.00         1960      5000     1.0           0
# 4  510000         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df['bathrooms'] = df['bathrooms'].astype(int)
df['floors'] = df['floors'].astype(int)

# %%
df.rename(columns={'yr_built':'age'},inplace=True)
df['age'] = 2023 - df['age']

# %%
df['age']
# Out:
# 0        68
# 1        72
# 2        90
# 3        58
# 4        36
#          ..
# 21608    14
# 21609     9
# 21610    14
# 21611    19
# 21612    15
# Name: age, Length: 21613, dtype: int64

# %%
df.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3          1         1180      5650       1           0
# 1  538000         3          2         2570      7242       2           0
# 2  180000         2          1          770     10000       1           0
# 3  604000         4          3         1960      5000       1           0
# 4  510000         3          2         1680      8080       1           0
#
#    view  condition  grade  sqft_above  sqft_basement  age  yr_renovated  \
# 0     0          3      7        1180              0   68             0
# 1     0          3      7        2170            400   72          1991
# 2     0          3      6         770              0   90             0
# 3     0          5      7        1050            910   58             0
# 4     0          3      8        1680              0   36             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# EDA

# %%
num = []

# %%
for i in df.select_dtypes(exclude='object').columns:
    num.append(i)

# %%
for i in num:
    sns.histplot(df[i])
    plt.xlabel(i)
    plt.ylabel('count')
    plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.scatterplot( x = df['sqft_living'], y = df['sqft_above'])
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_above'>

# %%
sns.boxplot( x = df['bedrooms'], y = df['price'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.boxplot( x = df['grade'], y = df['price'])
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
for i in num:
    Q1=df[i].quantile(0.25)
    Q3=df[i].quantile(0.75)
    IQR=Q3-Q1

IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df1=df[(df[i]>=lower_bound)&(df[i]<=upper_bound)]
print(df1)
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      221900         3          1         1180      5650       1           0
# 1      538000         3          2         2570      7242       2           0
# 2      180000         2          1          770     10000       1           0
# 3      604000         4          3         1960      5000       1           0
# 4      510000         3          2         1680      8080       1           0
# ...       ...       ...        ...          ...       ...     ...         ...
# 21608  360000         3          2         1530      1131       3           0
# 21609  400000         4          2         2310      5813       2           0
# 21610  402101         2          0         1020      1350       2           0
# 21611  400000         3          2         1600      2388       2           0
# 21612  325000         2          0         1020      1076       2           0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19419 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          19419 non-null  int64
#  1   bedrooms       19419 non-null  int64
#  2   bathrooms      19419 non-null  int32
#  3   sqft_living    19419 non-null  int64
#  4   sqft_lot       19419 non-null  int64
#  5   floors         19419 non-null  int32
#  6   waterfront     19419 non-null  int64
#  7   view           19419 non-null  int64
#  8   condition      19419 non-null  int64
#  9   grade          19419 non-null  int64
#  10  sqft_above     19419 non-null  int64
#  11  sqft_basement  19419 non-null  int64
#  12  age            19419 non-null  int64
#  13  yr_renovated   19419 non-null  int64
#  14  zipcode        19419 non-null  int64
#  15  lat            19419 non-null  float64
#  16  long           19419 non-null  float64
#  17  sqft_living15  19419 non-null  int64
# ...

# %%
x = df1.drop(columns=['price','yr_renovated','zipcode'],axis=1)
y = df1['price']

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          1         1180      5650       1           0     0
# 1         3          2         2570      7242       2           0     0
# 2         2          1          770     10000       1           0     0
# 3         4          3         1960      5000       1           0     0
# 4         3          2         1680      8080       1           0     0
#
#    condition  grade  sqft_above  sqft_basement  age      lat     long  \
# 0          3      7        1180              0   68  47.5112 -122.257
# 1          3      7        2170            400   72  47.7210 -122.319
# 2          3      6         770              0   90  47.7379 -122.233
# 3          5      7        1050            910   58  47.5208 -122.393
# 4          3      8        1680              0   36  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# ...

# %%
y.head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
#X_train=ms.fit_transform(x_train)
#X_test=ms.transform(x_test)

# %%
import ubml
metrics_performance,best_model=ubml.model_train_test(mode='regression',x_train=x_train,y_train=y_train,x_test=x_test,y_test=y_test)
# Out:
# c:\Users\purushoth\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.735e+14, tolerance: 1.659e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\purushoth\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\purushoth\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %%
print(best_model)
metrics_performance
# Out:
# Random Forest Regression
#                            r2 score train  r2 score test  \
# Linear Regression                   0.701          0.715
# Lasso Regression                    0.701          0.715
# Ridge Regression                    0.701          0.715
# Support Vector Regression          -0.056         -0.061
# Decision Tree Regression            0.999          0.750
# Random Forest Regression            0.980          0.890
#
#                            mean squared error train  mean squared error test  \
# Linear Regression                      3.190476e+10             3.075528e+10
# Lasso Regression                       3.190476e+10             3.075557e+10
# Ridge Regression                       3.190510e+10             3.076612e+10
# Support Vector Regression              1.127491e+11             1.144058e+11
# Decision Tree Regression               9.919607e+07             2.691385e+10
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor(max_depth=25,n_estimators=100,random_state=42)
RFR.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=25, random_state=42)

# %%
from sklearn.metrics import mean_squared_error

pred_train=RFR.predict(x_train)
pred_test=RFR.predict(x_test)

train_error=mean_squared_error(y_train,pred_train)
test_error=mean_squared_error(y_test,pred_test)

print("training error :",train_error)
print('test error :',test_error)
# Out:
# training error : 2039134842.6055038
# test error : 11448797000.2951

# %%
ypred=RFR.predict(x_test)
score=RFR.score(x_test,y_test)
print('accuracy : ',score)
# Out:
# accuracy :  0.8938345027182264

# %%
plt.figure(figsize=(5,5))
ax=sns.distplot(y_test,hist=False,color='r',label='Actual value')
sns.distplot(ypred,hist=False,color='b',label='predicted value',ax=ax)
plt.title('Actual value and predicited value')
plt.show()
# Out:
# C:\Users\purushoth\AppData\Local\Temp\ipykernel_6712\1978662654.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(y_test,hist=False,color='r',label='Actual value')
# C:\Users\purushoth\AppData\Local\Temp\ipykernel_6712\1978662654.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
import pickle
with open('model.pkl','wb') as file:
    pickle.dump(RFR, file)

# %%
features=np.array([[3,2,1680,8080,1,0,0,3,8,1680,0,36,47.6168,-122.045,1800,7503]])
ss=RFR.predict(features)
print(np.int64(ss))
# Out:
# [515413]
# c:\Users\purushoth\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
